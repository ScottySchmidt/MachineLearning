# %% [markdown]
# # Abstract Class
# Illinois State University; Data Structures; Scott Schmidt
#
# In the package edu.ilstu, create an abstract super class Person, two concrete subclass Employee and Student, and the driver
# testing class Test. If a method is an override method, you should include @Override.
#
# ![image.png](attachment:8d426758-c8c2-4b36-aee8-e18fc03da972.png)

# %% [markdown]
# # Person Super Class
#
# ![image.png](attachment:9636c7d5-9614-4099-add1-c24e9930983c.png)

# %%
class Person:
    
    PersonList=[]
    '''Create a Person Object'''
    def __init__(self, name, age, gender):
        self.name=name
        self.age=age
        self.gender=gender
          
    def getName():
        return name
    
    def getAge():
        return age
    
    def getGender():
        return gender
    
    def equals():
        found = False
        for person in Person.PersonList:
            if self.name == person[0] and self.age==person[1] and self.rate==person[4]:
                found = True
                print(self.name, self.age, self.rate, " found already exists")
                break
        if not found:
            print(self. name, " not found")
            return False

# %% [markdown]
# # Employee
#
# ![image.png](attachment:1b0a3fc2-70bd-4f7a-a23b-5ee4935ccb0c.png)

# %%
 class Employee(Person): 

    empList=[]
    '''Create a Person Object'''
    def __init__(self, name, age, gender, hour, rate):
        super().__init__(name, age, gender)
        self.hour=hour
        self.rate=rate
        
        eList=[name, age, gender, hour, rate]
        Employee.empList.append(list(eList))
        
    def getHour(self):
        return hour
    
    def getRate(self):
        return double
    
    def getPayment(self):
        '''The payment equals rate x hour.'''
        amount=self.hour*self.rate
        payment = "${:,.2f}".format(amount)
        return payment
    
    def toString(self):
        '''In the toString() method, you can use DecimalFormat df = new DecimalFormat("#.##");
        df.format(number) to format the decimal representation of the payment and average grade.'''
        pay=Employee.getPayment(self)
        print(self.name, self.age, self.gender," with pay of: ", pay)
        
    def equals(self):
        '''If two employees share the same name, age, and payment, they are the same person. '''
        found = False
        for person in Employee.empList:
            if self.name == person[0] and self.age==person[1] and self.rate==person[4]:
                found = True
                print(self.name, self.age, self.rate, " found already exists")
                break
        if not found:
            print(self. name, " not found")
            return False

# %% [markdown]
# # Student
#
# ![image.png](attachment:755a5a3e-3143-45f6-a18b-1e0afcdb2952.png)

# %%
 class Student(Person): 
    
    stuList=[]
    '''Create a Person Object'''
    def __init__(self, name, age, gender, major, totalGrade, numberOfCourses):
        super().__init__(name, age, gender)
        self.major=major
        self.totalGrade=totalGrade
        self.numberOfCourses=numberOfCourses
        
        sList=[name, age, gender, major, totalGrade, numberOfCourses]
        Student.stuList.append(list(sList))
        
    def getAverageGrade(self):
        '''The average grade equals the total grade divided by the number of courses'''
        return (self.totalGrade/self.numberOfCourses)
    
    def toString(self):
        print(self.name, self.major, (self.totalGrade/self.numberOfCourses) ) 
        
    def equals(self):
        '''If two students share the same name, age and major,they are the same person'''
        found = False
        for person in Student.stuList:
            if self.name == person[0] and self.age==person[1] and self.major==person[3]:
                found = True
                print(self.name, self.age, self.major, " found already exists")
                break
        if not found:
            print(self.name, " not found")
            return False

# %% [markdown]
# # Tester Class
#
# In the Test class, first, create two employee objects using the following listed arguments,
# then print out the objects’ information and compare these two objects to determine
# whether these two employees are the same person.
#
# Next, create two student objects using the following listed arguments, then print out the
# objects’ information and compare these two objects to determine whether these two
# students are the same person
#
# ![image.png](attachment:d91cea06-5ed8-403a-8cdb-74f55089075b.png)

# %%
emp0=Employee("Scott", 26, 'Male', 17.8, 22.7)
emp0.equals()

emp1=Employee("Linda Ward", 26, 'Female', 17.8, 22.7)
emp1.equals()
emp1.toString()

emp2=Employee("Linda Ward", 26, 'Female', 19.3, 17.18)
emp2.equals()

#STUDENT TESTS:
stu1=Student("James Smith", 21, 'Male', 'Computer Science', 350, 4)
stu1.toString()

stu2=Student("James Smith", 21, 'Male', 'Computer Science', 281, 3)
stu2.equals()
# Out:
# Scott 26 22.7  found already exists
# Linda Ward 26 22.7  found already exists
# Linda Ward 26 Female  with pay of:  $404.06
# Linda Ward 26 17.18  found already exists
# James Smith Computer Science 87.5
# James Smith 21 Computer Science  found already exists
